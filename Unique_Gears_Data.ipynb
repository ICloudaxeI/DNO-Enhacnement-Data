# %% [markdown]
# <a href="https://colab.research.google.com/github/ICloudaxeI/DNO-Enhancement-Data/blob/Unique/Unique_Gears_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Importing libaries for the data

# %%
import csv
import pandas as pd

from google.colab import drive

# %% [markdown]
# # Unique set
#
# As the players progress towards the end-game content, players must have a Unique set that can be crafted or obtained from Dragon raids. These Unique set will help them survive longer and deal more damage in order to clear faster and efficiently.

# %% [markdown]
# # Extracting U Grades data from the csv file

# %% [markdown]
# Getting the saved csv file from the Google Drive Directory

# %%
# Reading the csv file from the Google Drive Directory
drive.mount('/content/drive')
csv_file_path = '/content/drive/MyDrive/Enhancement_data/data.csv'

df = pd.read_csv(csv_file_path)
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                             Item Name  EnchantLevel  EnchantRatio  BreakRatio  \
# 0             Ancient Totem Arm Blade             1         100.0         0.0
# 1             Ancient Totem Arm Blade             2         100.0         0.0
# 2             Ancient Totem Arm Blade             3         100.0         0.0
# 3             Ancient Totem Arm Blade             4         100.0         0.0
# 4             Ancient Totem Arm Blade             5         100.0         0.0
# ...                               ...           ...           ...         ...
# 23290  Twisted obsession Wrist Guards            11          25.0        25.0
# 23291  Twisted obsession Wrist Guards            12          20.0        25.0
# 23292  Twisted obsession Wrist Guards            13          15.0        25.0
# ...

# %% [markdown]
# Create a function that calls the name of the item and getting their row number to convert in to a string

# %%
def get_item_info(keyword):
    # Filter the DataFrame to get all columns for items containing the keyword
    item_info = df[df['Item Name'].str.contains(keyword, case=False)]

    return item_info

additional_words = ['Destroyer', 'Illumia',             # L grade warrior
                    'Troublemaker ', 'Tracker',         # L grade archer
                    'Saviour', 'Guardian Knight',       # L grade cleric
                    'Contractor', 'Terminator',         # L grade sorceress
                    'Changer', 'Coordinator',           # L grade academic
                    'Soul Handler', 'Dancer',           # L grade kali
                    'Slaughter', 'Meditation',          # L grade assassin
                    'Victoria']                         # L grade lancea

def filter_items(item_info, additional_words):
    # Convert additional words list to lowercase
    additional_words = [word.lower() for word in additional_words]

    # Function to check if item name contains any additional words
    def contains_additional_words(item_name):
        item_name_lower = item_name.lower()
        for word in additional_words:
            if word in item_name_lower:
                return True
        return False

    # Apply the filter
    filtered_info = item_info[~item_info['Item Name'].apply(contains_additional_words)]
    return filtered_info

# %% [markdown]
# Testing the created function

# %%
keyword_test = "Manticore"  # Replace with the keyword you want to search for
test_info = get_item_info(keyword_test)

test_info
# Out:
#                     Item Name  EnchantLevel  EnchantRatio  BreakRatio  \
# 16740     Manticore Arm Blade             1         100.0         0.0
# 16741     Manticore Arm Blade             2         100.0         0.0
# 16742     Manticore Arm Blade             3         100.0         0.0
# 16743     Manticore Arm Blade             4         100.0         0.0
# 16744     Manticore Arm Blade             5         100.0         0.0
# ...                       ...           ...           ...         ...
# 17710  Manticore Wrist Guards            11          25.0        25.0
# 17711  Manticore Wrist Guards            12          20.0        25.0
# 17712  Manticore Wrist Guards            13          15.0        25.0
# 17713  Manticore Wrist Guards            14           5.0        25.0
# 17714  Manticore Wrist Guards            15           1.0        25.0
#
#        MinDowngrade  MaxDowngrade  Gold
# 16740             0             0     0
# 16741             0             0     0
# ...

# %% [markdown]
# # Unique sets in Dragon Nest

# %% [markdown]
# The list of Unique within the csv file
#
# 1. Sea Dragon set (Missing data)
# 2. Green/Emerald Dragon set
# 3. Desert Dragon set
# 4. Black Dragon set
# 5. Red Dragon set

# %%
# Sea Dragon set
keyword_SDN = "Sea Dragon" # Missing Data

# Green/Emerald Dragon set
keyword_EGDN = "Emerald Dragon"

# Desert Dragon set
keyword_DDN = "Desert Dragon"

# Black Dragon set
keyword_BDN = "Black Dragon"

# Red Dragon set
keyword_RDN = "Red Dragon"

# %% [markdown]
# 1. Sea Dragon Set

# %%
keyword_U1 = keyword_SDN  # Replace with the keyword you want to search for
item_info_U1 = get_item_info(keyword_U1)
item_info_U1 = filter_items(item_info_U1, additional_words)

item_info_U1
# Out:
# Empty DataFrame
# Columns: [Item Name, EnchantLevel, EnchantRatio, BreakRatio, MinDowngrade, MaxDowngrade, Gold]
# Index: []

# %%
# Save the selected rows to a new CSV file
#item_info_U1.to_csv('/content/drive/MyDrive/Enhancement_data/Unique/SDN/SDN.csv', index=False)

# %% [markdown]
# 2. Green/Emerald Dragon set

# %%
keyword_U2 = keyword_EGDN  # Replace with the keyword you want to search for
item_info_U2 = get_item_info(keyword_U2)
item_info_U2 = filter_items(item_info_U2, additional_words)

item_info_U2
# Out:
#                          Item Name  EnchantLevel  EnchantRatio  BreakRatio  \
# 10185     Emerald Dragon Arm Blade             1         100.0         0.0
# 10186     Emerald Dragon Arm Blade             2         100.0         0.0
# 10187     Emerald Dragon Arm Blade             3         100.0         0.0
# 10188     Emerald Dragon Arm Blade             4         100.0         0.0
# 10189     Emerald Dragon Arm Blade             5         100.0         0.0
# ...                            ...           ...           ...         ...
# 12835  Emerald Dragon Wrist Guards            11          25.0        25.0
# 12836  Emerald Dragon Wrist Guards            12          20.0        25.0
# 12837  Emerald Dragon Wrist Guards            13          15.0        25.0
# 12838  Emerald Dragon Wrist Guards            14           5.0        25.0
# 12839  Emerald Dragon Wrist Guards            15           1.0        25.0
#
#        MinDowngrade  MaxDowngrade  Gold
# ...

# %%
# Save the selected rows to a new CSV file
item_info_U2.to_csv('/content/drive/MyDrive/Enhancement_data/Unique/EGDN/EGDN.csv', index=False)

# %% [markdown]
# 3. Desert Dragon set

# %%
keyword_U3 = keyword_DDN  # Replace with the keyword you want to search for
item_info_U3 = get_item_info(keyword_U3)
item_info_U3 = filter_items(item_info_U3, additional_words)

item_info_U3
# Out:
#                         Item Name  EnchantLevel  EnchantRatio  BreakRatio  \
# 7530      Desert Dragon Arm Blade             1         100.0         0.0
# 7531      Desert Dragon Arm Blade             2         100.0         0.0
# 7532      Desert Dragon Arm Blade             3         100.0         0.0
# 7533      Desert Dragon Arm Blade             4         100.0         0.0
# 7534      Desert Dragon Arm Blade             5         100.0         0.0
# ...                           ...           ...           ...         ...
# 10180  Desert Dragon Wrist Guards            11          25.0        25.0
# 10181  Desert Dragon Wrist Guards            12          20.0        25.0
# 10182  Desert Dragon Wrist Guards            13          15.0        25.0
# 10183  Desert Dragon Wrist Guards            14           5.0        25.0
# 10184  Desert Dragon Wrist Guards            15           1.0        25.0
#
#        MinDowngrade  MaxDowngrade  Gold
# ...

# %%
# Save the selected rows to a new CSV file
item_info_U3.to_csv('/content/drive/MyDrive/Enhancement_data/Unique/DDN/DDN.csv', index=False)

# %% [markdown]
# 4. Black Dragon set

# %%
keyword_U4 = keyword_BDN  # Replace with the keyword you want to search for
item_info_U4 = get_item_info(keyword_U4)
item_info_U4 = filter_items(item_info_U4, additional_words)

item_info_U4
# Out:
#                       Item Name  EnchantLevel  EnchantRatio  BreakRatio  \
# 1950     Black Dragon Arm Blade             1         100.0         0.0
# 1951     Black Dragon Arm Blade             2         100.0         0.0
# 1952     Black Dragon Arm Blade             3         100.0         0.0
# 1953     Black Dragon Arm Blade             4         100.0         0.0
# 1954     Black Dragon Arm Blade             5         100.0         0.0
# ...                         ...           ...           ...         ...
# 4600  Black Dragon Wrist Guards            11          25.0        25.0
# 4601  Black Dragon Wrist Guards            12          20.0        25.0
# 4602  Black Dragon Wrist Guards            13          15.0        25.0
# 4603  Black Dragon Wrist Guards            14           5.0        25.0
# 4604  Black Dragon Wrist Guards            15           1.0        25.0
#
#       MinDowngrade  MaxDowngrade  Gold
# 1950             0             0     4
# ...

# %%
# Save the selected rows to a new CSV file
item_info_U4.to_csv('/content/drive/MyDrive/Enhancement_data/Unique/BDN/BDN.csv', index=False)

# %% [markdown]
# 5. Red Dragon set

# %%
keyword_U5 = keyword_RDN  # Replace with the keyword you want to search for
item_info_U5 = get_item_info(keyword_U5)
item_info_U5 = filter_items(item_info_U5, additional_words)

item_info_U5
# Out:
#                      Item Name  EnchantLevel  EnchantRatio  BreakRatio  \
# 19665     Red Dragon Arm Blade             1         100.0         0.0
# 19666     Red Dragon Arm Blade             2         100.0         0.0
# 19667     Red Dragon Arm Blade             3         100.0         0.0
# 19668     Red Dragon Arm Blade             4         100.0         0.0
# 19669     Red Dragon Arm Blade             5         100.0         0.0
# ...                        ...           ...           ...         ...
# 20635  Red Dragon Wrist Guards            11           7.0        25.0
# 20636  Red Dragon Wrist Guards            12           5.0        25.0
# 20637  Red Dragon Wrist Guards            13           1.0        25.0
# 20638  Red Dragon Wrist Guards            14           1.0        25.0
# 20639  Red Dragon Wrist Guards            15           1.0        25.0
#
#        MinDowngrade  MaxDowngrade  Gold
# 19665             0             0     4
# ...

# %%
# Save the selected rows to a new CSV file
item_info_U5.to_csv('/content/drive/MyDrive/Enhancement_data/Unique/RDN/RDN.csv', index=False)

# %% [markdown]
# # Making the bulk csv file of Unique set in one csv

# %% [markdown]
# Create a function that combines all `str_row_indices` into an array and convert it into csv

# %%
# List containing all item_info_
all_item_info_list = [
    item_info_U1,
    item_info_U2,
    item_info_U3,
    item_info_U4,
    item_info_U5
]

# Output CSV file path in Google Drive
output_csv_file = 'all_U_gears.csv'

# Write the filtered rows to the CSV file in Google Drive
with open('/content/drive/MyDrive/Enhancement_data/Unique/' + output_csv_file, 'w', newline='') as output_csv:
    writer = csv.writer(output_csv)
    # Write Header
    writer.writerow(['Item Name', 'EnchantLevel', 'EnchantRatio', 'BreakRatio', 'MinDowngrade', 'MaxDowngrade', 'Gold'])

    # Write rows corresponding to the filtered DataFrames
    for item_info in all_item_info_list:
        # Write each row to the output CSV file
        for _, row in item_info.iterrows():
            writer.writerow(row)

print(f"Combined rows saved to '{output_csv_file}' in Google Drive")
# Out:
# Combined rows saved to 'all_U_gears.csv' in Google Drive
